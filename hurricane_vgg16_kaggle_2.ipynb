# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import matplotlib.pyplot as plt
import seaborn as sns
#from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
# Specify the path to the ZIP file
zip_file_path = '/content/drive/MyDrive/hurricane_damage.zip'

# Specify the directory where you want to extract the contents
extract_to_dir = '/content/'

# Create a ZipFile object
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all contents to the specified directory
    zip_ref.extractall(extract_to_dir)

print(f"Files extracted to: {extract_to_dir}")
# Out:
# Files extracted to: /content/

# %% [markdown]
# ### creating dataframe

# %%
image_dir_test=Path('/content/archive/test')
image_dir_train=Path('/content/archive/train_another')
image_dir_val=Path('/content/archive/validation_another')

filepaths_test= list(image_dir_test.glob(r'**/*.jpeg'))
filepaths_train= list(image_dir_train.glob(r'**/*.jpeg'))
filepaths_val= list(image_dir_val.glob(r'**/*.jpeg'))

labels_test=list(map(lambda x: os.path.split(os.path.split(x)[0])[1],filepaths_test))
labels_train=list(map(lambda x: os.path.split(os.path.split(x)[0])[1],filepaths_train))
labels_val=list(map(lambda x: os.path.split(os.path.split(x)[0])[1],filepaths_val))

# %%
filepaths_test=pd.Series(filepaths_test,name='Filepath').astype(str)
labels_test=pd.Series(labels_test,name='Label')
image_df_test=pd.concat([filepaths_test,labels_test],axis=1)
image_df_test
# Out:
#                                                Filepath      Label
# 0     /content/archive/test/damage/-96.898065_28.459...     damage
# 1     /content/archive/test/damage/-95.649434_29.833...     damage
# 2     /content/archive/test/damage/-95.649469_29.838...     damage
# 3     /content/archive/test/damage/-95.590248_29.767...     damage
# 4     /content/archive/test/damage/-97.000315_28.532...     damage
# ...                                                 ...        ...
# 1995  /content/archive/test/no_damage/-95.636787_29....  no_damage
# 1996  /content/archive/test/no_damage/-95.29906_29.5...  no_damage
# 1997  /content/archive/test/no_damage/-95.271377_29....  no_damage
# 1998  /content/archive/test/no_damage/-95.652637_29....  no_damage
# 1999  /content/archive/test/no_damage/-95.6349939999...  no_damage
#
# [2000 rows x 2 columns]

# %%
filepaths_train=pd.Series(filepaths_train,name='Filepath').astype(str)
labels_train=pd.Series(labels_train,name='Label')
image_df_train=pd.concat([filepaths_train,labels_train],axis=1)
image_df_train
# Out:
#                                                Filepath      Label
# 0     /content/archive/train_another/damage/-95.6288...     damage
# 1     /content/archive/train_another/damage/-95.6285...     damage
# 2     /content/archive/train_another/damage/-95.5943...     damage
# 3     /content/archive/train_another/damage/-95.6449...     damage
# 4     /content/archive/train_another/damage/-95.6494...     damage
# ...                                                 ...        ...
# 9995  /content/archive/train_another/no_damage/-95.0...  no_damage
# 9996  /content/archive/train_another/no_damage/-95.2...  no_damage
# 9997  /content/archive/train_another/no_damage/-95.1...  no_damage
# 9998  /content/archive/train_another/no_damage/-95.6...  no_damage
# 9999  /content/archive/train_another/no_damage/-96.9...  no_damage
#
# [10000 rows x 2 columns]

# %%
filepaths_val=pd.Series(filepaths_val,name='Filepath').astype(str)
labels_val=pd.Series(labels_val,name='Label')
image_df_val=pd.concat([filepaths_val,labels_val],axis=1)
image_df_val
# Out:
#                                                Filepath      Label
# 0     /content/archive/validation_another/damage/-95...     damage
# 1     /content/archive/validation_another/damage/-95...     damage
# 2     /content/archive/validation_another/damage/-96...     damage
# 3     /content/archive/validation_another/damage/-95...     damage
# 4     /content/archive/validation_another/damage/-93...     damage
# ...                                                 ...        ...
# 1995  /content/archive/validation_another/no_damage/...  no_damage
# 1996  /content/archive/validation_another/no_damage/...  no_damage
# 1997  /content/archive/validation_another/no_damage/...  no_damage
# 1998  /content/archive/validation_another/no_damage/...  no_damage
# 1999  /content/archive/validation_another/no_damage/...  no_damage
#
# [2000 rows x 2 columns]

# %%
print(image_df_train.shape)
print(image_df_test.shape)
print(image_df_val.shape)
# Out:
# (10000, 2)
# (2000, 2)
# (2000, 2)

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMAGE_SIZE = [IMG_HEIGHT,IMG_WIDTH]
BATCH_SIZE = 64
NUM_OF_CLASSES = 1
EPOCHS = 30

train_generator= keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
val_generator= keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_generator= keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_images=train_generator.flow_from_dataframe(
    dataframe=image_df_train,
    x_col='Filepath',
    y_col='Label',
    target_size=(IMG_HEIGHT,IMG_WIDTH),
    color_mode='rgb',
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_images=val_generator.flow_from_dataframe(
    dataframe=image_df_val,
    x_col='Filepath',
    y_col='Label',
    target_size=(IMG_HEIGHT,IMG_WIDTH),
    color_mode='rgb',
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_images=test_generator.flow_from_dataframe(
    dataframe=image_df_test,
    x_col='Filepath',
    y_col='Label',
    target_size=(IMG_HEIGHT,IMG_WIDTH),
    color_mode='rgb',
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 10000 validated image filenames belonging to 2 classes.
# Found 2000 validated image filenames belonging to 2 classes.
# Found 2000 validated image filenames belonging to 2 classes.

# %%
plt.figure(figsize=(15,15))
for images, labels in test_images:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        #plt.title(int(labels[i]))
        plt.axis("off")
    break

# %%
plt.figure(figsize=(15,15))
for images, labels in train_images:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        #plt.title(int(labels[i]))
        plt.axis("off")
    break

# %%
plt.figure(figsize=(15,15))
for images, labels in val_images:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        #plt.title(int(labels[i]))
        plt.axis("off")
    break

# %% [markdown]
# ### Model

# %%
from keras.models import Sequential
from tensorflow import keras
from keras.layers import Flatten, Dense
from keras.applications import VGG16

input_shape = (128,128,3)
ACTIVATION = 'relu'
PADDING = 'same'
DROPOUT_RATE = 0.1
EPSILON = 0.001

vgg16 = VGG16(input_shape=(IMG_HEIGHT,IMG_WIDTH, 3), weights='imagenet', include_top=False)
# Freeze layers
for layer in vgg16.layers:
    layer.trainable = False

# Create a Sequential model
model = Sequential()
model.add(vgg16)
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=keras.optimizers.Adam(0.001),
              metrics=['accuracy',keras.metrics.Precision(),keras.metrics.Recall()])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1)                 8193
#
# =================================================================
# Total params: 14722881 (56.16 MB)
# Trainable params: 8193 (32.00 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
history=model.fit(
    train_images,
    validation_data=val_images,
    epochs=EPOCHS,

    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=4,
            restore_best_weights=True
        ),
         tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            patience=3
        )
    ]
)
# Out:
# Epoch 1/30
# 157/157 [==============================] - 30s 115ms/step - loss: 0.3084 - accuracy: 0.8752 - precision: 0.8819 - recall: 0.8664 - val_loss: 0.2327 - val_accuracy: 0.9135 - val_precision: 0.9189 - val_recall: 0.9070 - lr: 0.0010
# Epoch 2/30
# 157/157 [==============================] - 15s 94ms/step - loss: 0.2162 - accuracy: 0.9139 - precision: 0.9219 - recall: 0.9044 - val_loss: 0.2278 - val_accuracy: 0.9065 - val_precision: 0.9462 - val_recall: 0.8620 - lr: 0.0010
# Epoch 3/30
# 157/157 [==============================] - 15s 97ms/step - loss: 0.1996 - accuracy: 0.9190 - precision: 0.9249 - recall: 0.9120 - val_loss: 0.2113 - val_accuracy: 0.9240 - val_precision: 0.9109 - val_recall: 0.9400 - lr: 0.0010
# Epoch 4/30
# 157/157 [==============================] - 18s 117ms/step - loss: 0.1801 - accuracy: 0.9293 - precision: 0.9373 - recall: 0.9202 - val_loss: 0.2065 - val_accuracy: 0.9285 - val_precision: 0.9140 - val_recall: 0.9460 - lr: 0.0010
# Epoch 5/30
# 157/157 [==============================] - 15s 97ms/step - loss: 0.1669 - accuracy: 0.9353 - precision: 0.9428 - recall: 0.9268 - val_loss: 0.1995 - val_accuracy: 0.9300 - val_precision: 0.9159 - val_recall: 0.9470 - lr: 0.0010
# Epoch 6/30
# 157/157 [==============================] - 15s 98ms/step - loss: 0.1602 - accuracy: 0.9377 - precision: 0.9433 - recall: 0.9314 - val_loss: 0.1974 - val_accuracy: 0.9340 - val_precision: 0.9181 - val_recall: 0.9530 - lr: 0.0010
# Epoch 7/30
# 157/157 [==============================] - 15s 98ms/step - loss: 0.1518 - accuracy: 0.9410 - precision: 0.9469 - recall: 0.9344 - val_loss: 0.1885 - val_accuracy: 0.9300 - val_precision: 0.9300 - val_recall: 0.9300 - lr: 0.0010
# Epoch 8/30
# 157/157 [==============================] - 15s 98ms/step - loss: 0
30
# 157/157 [==============================] - 15s 98ms/step - loss: 0.0932 - accuracy: 0.9700 - precision: 0.9753 - recall: 0.9644 - val_loss: 0.1820 - val_accuracy: 0.9360 - val_precision: 0.9343 - val_recall: 0.9380 - lr: 1.0000e-04
# Epoch 21/30
# 157/157 [==============================] - 18s 115ms/step - loss: 0.0928 - accuracy: 0.9698 - precision: 0.9751 - recall: 0.9642 - val_loss: 0.1822 - val_accuracy: 0.9355 - val_precision: 0.9342 - val_recall: 0.9370 - lr: 1.0000e-04
# Epoch 22/30
# 157/157 [==============================] - 15s 98ms/step - loss: 0.0921 - accuracy: 0.9710 - precision: 0.9750 - recall: 0.9668 - val_loss: 0.1820 - val_accuracy: 0.9350 - val_precision: 0.9350 - val_recall: 0.9350 - lr: 1.0000e-05
# Epoch 23/30
# 157/157 [==============================] - 18s 116ms/step - loss: 0.0921 - accuracy: 0.9706 - precision: 0.9765 - recall: 0.9644 - val_loss: 0.1823 - val_accuracy: 0.9365 - val_precision: 0.9343 - val_recall: 0.9390 - lr: 1.0000e-05
# Epoch 24/30
# 157/157 [==============================] - 15s 98ms/step - loss: 0.0921 - accuracy: 0.9705 - precision: 0.9748 - recall: 0.9660 - val_loss: 0.1821 - val_accuracy: 0.9350 - val_precision: 0.9341 - val_recall: 0.9360 - lr: 1.0000e-05
# Epoch 25/30
# 157/157 [==============================] - 16s 100ms/step - loss: 0.0920 - accuracy: 0.9702 - precision: 0.9751 - recall: 0.9650 - val_loss: 0.1821 - val_accuracy: 0.9355 - val_precision: 0.9342 - val_recall: 0.9370 - lr: 1.0000e-06
# Epoch 26/30
# 157/157 [==============================] - 15s 98ms/step - loss: 0.0920 - accuracy: 0.9702 - precision: 0.9751 - recall: 0.9650 - val_loss: 0.1822 - val_accuracy: 0.9355 - val_precision: 0.9342 - val_recall: 0.9370 - lr: 1.0000e-06

# %%
model.save('hurricane_vgg16_2.h5')

# %%
results=model.evaluate(test_images)
print("test loss: {:.5f}".format(results[0]))
print("test acc: {:.2f}".format(results[1]*100))
predictions=(model.predict(test_images)>=0.5).astype(int)
cm=confusion_matrix(test_images.labels,predictions,labels=[0,1])
plt.figure(figsize=(6,6))
sns.heatmap(cm,annot=True,fmt='g',vmin=0,cmap='Blues',cbar=False)
plt.xticks(ticks=[0.5,1.5],label=["no_damage","damage"])
plt.yticks(ticks=[0.5,1.5],label=["no_damage","damage"])
plt.xlabel("predicted")
plt.ylabel("actual")
plt.title("confusion matrix")
plt.show
# Out:
# 32/32 [==============================] - 4s 111ms/step - loss: 0.1521 - accuracy: 0.9455 - precision: 0.9459 - recall: 0.9450
# test loss: 0.15209
# test acc: 94.55
# 32/32 [==============================] - 3s 76ms/step
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
results = model.evaluate(val_images,batch_size=16)
print("Loss:", results[0])
print("Accuracy:", results[1])
print("Precision:", results[2])
print("Recall:", results[3])
# Out:
# 32/32 [==============================] - 3s 103ms/step - loss: 0.1820 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350
# Loss: 0.1820029318332672
# Accuracy: 0.9350000023841858
# Precision: 0.9350000023841858
# Recall: 0.9350000023841858

# %%
results = model.evaluate(test_images,batch_size=16)
print("Loss:", results[0])
print("Accuracy:", results[1])
print("Precision:", results[2])
print("Recall:", results[3])
# Out:
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1521 - accuracy: 0.9455 - precision: 0.9459 - recall: 0.9450
# Loss: 0.15208669006824493
# Accuracy: 0.9455000162124634
# Precision: 0.9459459185600281
# Recall: 0.9449999928474426

# %%
import matplotlib.pyplot as plt

# Assuming `history` contains the training history

# Extracting metrics
loss = history.history['loss']
accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

# Number of epochs
epochs = range(1, len(loss) + 1)

# Plotting subplots
plt.figure(figsize=(15, 10))

# Loss subplot
plt.subplot(2, 1, 1)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy subplot
plt.subplot(2, 1, 2)
plt.plot(epochs, accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 20.1 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2

# %%
import visualkeras
visualkeras.layered_view(model, legend=True) # without custom font
from PIL import ImageFont
#font = ImageFont.truetype("arial.ttf", 12)
visualkeras.layered_view(model, legend=True) # selected font
# Out:
# <PIL.Image.Image image mode=RGBA size=518x63>
